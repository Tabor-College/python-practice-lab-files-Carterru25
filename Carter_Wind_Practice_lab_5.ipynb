# %%
def greet_user():
  """Ask user for their name and greet them"""
  name = input("Enter Your name: ")
  print(f"hello, {name}! Welcome to the course.")

greet_user()
# Out:
# Enter Your name: Carter
# hello, Carter! Welcome to the course.

# %%
def calculate_total(price, quanity): # price, quanity are parameters
    total = price * quanity
    return total

# Calling the function with arguments
items_price = 19.99
item_quanity = 3
bill_total = calculate_total(items_price, item_quanity)
print("Total bill:", bill_total)
# Out:
# Total bill: 59.97

# %%
def checkout(amount, shipping=5.0):
  final_amount = amount + shipping
  return final_amount

print("order 1 total:", checkout(50))
print("order 2:", checkout(50, shipping=10))
# Out:
# order 1 total: 55.0
# order 2: 60

# %%
def register_student(name, program, year):
  print("-------Student Registration-------")
  print("Name:", name)
  print("Program:", program)
  print("Year:", year)
  print("--------------------------------")

register_student("anu", "Computer Science", 1)

register_student(year= 2, name="Rahul", program="Data Science")
#
# Out:
# -------Student Registration-------
# Name: anu
# Program: Computer Science
# Year: 1
# --------------------------------
# -------Student Registration-------
# Name: Rahul
# Program: Data Science
# Year: 2
# --------------------------------

# %%
def average_score(*scores):
  if not scores:
    print("No scores provided.")
    return None

  total = sum(scores)
  avg = total/len(scores)
  print(f"scores: {scores}")
  print(f"average: {avg}")
  return avg

average_score(80, 90, 75)
average_score(100, 95)
average_score()
# Out:
# scores: (80, 90, 75)
# average: 81.66666666666667
# scores: (100, 95)
# average: 97.5
# No scores provided.

# %%
def create_profile(**info):
  if not info:
    print("Empty profile")
    return

  print("-------Profile--------")
  for key, value in info.items():
    print(f"{key.capitalize()}: {value}")
  print("--------------------")

create_profile(name="K", role="Proffesor", Department="CS")
create_profile(name="Sam", City="Sacramento")
create_profile()
# Out:
# -------Profile--------
# Name: K
# Role: Proffesor
# Department: CS
# --------------------
# -------Profile--------
# Name: Sam
# City: Sacramento
# --------------------
# Empty profile

# %%
def log_event(event_type, *details, **metadata):
  print("===Event Log===")
  print(f"Type: {event_type}")

  if details:
    print(f"Details: {details}")
  else:
    print("Details: (none)")

  if metadata:
    print("Metadata:")
    for key, value in metadata.items():
      print(f"{key}: {value}")
  else:
    print("Metadata: (none)")
  print("================")

log_event("LOGIN", "Success", user="K", ip="192.168.0.10")
log_event("FILE_UPLOAD", "report.pdf", size="2MB")
log_event("PING")
# Out:
# ===Event Log===
# Type: LOGIN
# Details: ('Success',)
# Metadata:
# user: K
# ip: 192.168.0.10
# ================
# ===Event Log===
# Type: FILE_UPLOAD
# Details: ('report.pdf',)
# Metadata:
# size: 2MB
# ================
# ===Event Log===
# Type: PING
# Details: (none)
# Metadata: (none)
# ================

# %%
def analyse_sales(sales):
  if not sales:
    return None, None, 0, 0

  min_sale = min(sales)
  max_sale = max(sales)
  total = sum(sales)
  average_sale = total/len(sales)
  return min_sale, max_sale, total, average_sale

week_sales = [120, 150, 90, 200, 175]
min_s, max_s, total_s, avg_s = analyse_sales(week_sales)

print(f"Min sale: ${min_s}")
print(f"Max sale: ${max_s}")
print(f"Total sale: ${total_s}")
print(f"Average sale: ${avg_s:2f}")
# Out:
# Min sale: $90
# Max sale: $200
# Total sale: $735
# Average sale: $147.000000

# %%
balance = 1000

def deposit_correct(ammount):
  global balance
  balance = balance + ammount
  print(f"Depsoited ${ammount}. New balance: ${balance}")

def deposit_wrong(ammount):
  balance = balance + ammount
  return balance

print("Initial balance", balance)
deposit_correct(200)
print("Final balance", balance)
# Out:
# Initial balance 1000
# Depsoited $200. New balance: $1200
# Final balance 1200

# %%
def ten_percent_discount(amount):
  return amount * 0.9

def five_percent_discount(amount):
  return amount - 5

def apply_discount(amount, discount_func):
  new_ammount = discount_func(amount)
  print(f"Origonal: ${amount}, After discount: ${new_ammount}")
  return new_ammount

apply_discount(100, ten_percent_discount)
apply_discount(100, five_percent_discount)
# Out:
# Origonal: $100, After discount: $90.0
# Origonal: $100, After discount: $95
# 95

# %%
square = lambda x:x **2
print(square(5))

products = [
    ("Notebook", 4.99),
    ("Pen", 1.49),
    ("Backpack", 29.99)
    ("Bottle", 9.99)
]

sorted_by_price = sorted(products, key=lambda x:x[1])
print("Print sorted by price:")
for name, price in sorted_by_price:
  print(f" {name}:${price}")
# Out:
# 25
# Print sorted by price:
#  Pen:$1.49
#  Notebook:$4.99
#  Bottle:$9.99
#  Backpack:$29.99

# %%
def celsius_to_fahrenheit(c):

  return (c * 9/5) + 32

result = celsius_to_fahrenheit(37)
print(f"37C in Fahrenheit = {result}F")

print("\nDocstring:")
print(celsius_to_fahrenheit.__doc__)
# Out:
# 37C in Fahrenheit = 98.6F
#
# Docstring:
# None
