# %% [markdown]
# # CS201 First day of notes

# %% [markdown]
# ### Variables

# %%
student_name = "Alice"

# %%
age = 20

# %%
height = 1.65

# %%
is_enrolled = True

# %%
print(student_name)
# Out:
# Alice

# %%
print(age)
# Out:
# 20

# %%
print(type(age))
# Out:
# <class 'int'>

# %% [markdown]
# ### Data Types

# %%
x = 10

# %%
y = 3

# %%
print(x + y)
# Out:
# 13

# %%
a = "10"

# %%
b = "3"

# %%
print(a + b)
# Out:
# 103

# %% [markdown]
# ### Dynamic Typing and Debugging

# %%
value = 42

# %%
print(type(value))
# Out:
# <class 'int'>

# %%
value = "hello"

# %%
print(type(value))
# Out:
# <class 'str'>

# %%
print(type(value))
# Out:
# <class 'str'>

# %% [markdown]
# ### Variable Naming

# %%
hours_worked = 5

# %%
hourly_rate = 10

# %%
total_pay = hours_worked * hourly_rate

# %%
print(total_pay)
# Out:
# 50

# %% [markdown]
# ### Conditions if/else

# %%
age = 16

# %%
if age >= 18:
    print("Adult")
else:
    print("Minor")
# Out:
# Minor

# %%
print(age >= 18)
# Out:
# False

# %% [markdown]
# ### Multiple Conditions elif

# %%
score = 82

# %%
if score >= 90:
    print("A")
elif score >= 80:
    print("B")
elif score >= 70:
    print("C")
else:
    print("F")
# Out:
# B

# %% [markdown]
# ### Readible & Pythonic Codnnitions

# %%
# bad

# %%
age = 20

# %%
if not (age < 18 or age > 65):
    print("Adult")
# Out:
# Adult

# %%
# Pythonic and clean

# %%
if 18 <= age <= 65:
    print("Adult")
# Out:
# Adult

# %% [markdown]
# ### Input and Output

# %%
name = input("Enter your name:")
print("Hello", name)
# Out:
# Enter your name: Carter
# Hello Carter

# %% [markdown]
# ### Input always returns text

# %%
age = input("Enter age:")
print(age)
print(type(age))
# Out:
# Enter age: 20
# 20
# <class 'str'>

# %% [markdown]
# ### Type Conversion

# %%
age = int(input("Enter age:"))20
# Out:
# Enter age: 20

# %%
height = float(input("Enter height:"))
# Out:
# Enter height: 20

# %%
c=int(input("Enter temprature in Celsius:"))
f=(c*9/5)+32
print(f"Temprature in Farenheight is",f)
if c>25:
    print("go to the beach")
elif c>15:
    print("go hiking")
else:
    print("Stay inside")
# Out:
# Enter temprature in Celsius: 22
# Temprature in Farenheight is 71.6
# go hiking

# %%
import random
n=random.randint(1,10)
g=0
a=input(f"What is your name?:")
print(f"Hello", a, f"Guess a number between 1 and 10")
while g<3:
    u=int(input(f"Enter your guess"))
    g=g+1
    if u==n:
        print(a,"You won!")
        break
    elif u<n:
        print(f"Too low")
    else:
        print("Too high")
if u!=n:
    print("Game over. The number was", n)
# Out:
# What is your name?: Carter
# Hello Carter Guess a number between 1 and 10
# Enter your guess 7
# Too low
# Enter your guess 9
# Too high
# Enter your guess 8
# Carter You won!

# %%
name = "Carter"
print(name)

name = name + "Wind"
print(name)
# Out:
# Carter
# CarterWind

# %%
first = "Hello" 
second = "world"

print(first + " " + second)
# Out:
# Hello world

# %%
age = "20"
print("age: " + age)
# Out:
# age: 20

# %%
age = "20"
print("age: " + str(age))
# Out:
# age: 20

# %%
name = "carter"
age = 20
print(f"My name is

# %%
# integer 
student_age = 20
# string
student_name = "john"
# float
student_grade = 80.5
# boolan
student_project = False
# constant
MAX_TRYS = 20
# input
favorite_color = input("What is your favorite color?: ")
# Out:
# What is your favorite color?:  blue

# %%
# type conversion
x = int(input("Enter value:"))
x = float(input("Enter values:"))
# Out:
# Enter value: 20
# Enter values: 3.14

# %%
import math

a = 4
b = 5

print(a + b)
print(a - b)
print(a * b)
print(a / b)
print(a // b)
print(a ** b)
print(a % b)
# Out:
# 9
# -1
# 20
# 0.8
# 0
# 1024
# 4

# %%
age = int(input("How old are you?: "))
if age >= 65:
    print("senior")
    
elif age >= 18:
    print("Adult")
    
else:
    print("minor")
# Out:
# How old are you?:  65
# senior

# %%
ord('a')
# Out:
# 97

# %%
ord('A')
# Out:
# 65

# %%
import math
dir(math)
# Out:
# ['__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'acos',
#  'acosh',
#  'asin',
#  'asinh',
#  'atan',
#  'atan2',
#  'atanh',
#  'cbrt',
#  'ceil',
#  'comb',
#  'copysign',
#  'cos',
#  'cosh',
#  'degrees',
#  'dist',
#  'e',
#  'erf',
#  'erfc',
#  'exp',
#  'exp2',
#  'expm1',
#  'fabs',
#  'factorial',
#  'floor',
#  'fma',
#  'fmod',
#  'frexp',
#  'fsum',
#  'gamma',
#  'gcd',
#  'hypot',
#  'inf',
#  'isclose',
#  'isfinite',
#  'isinf',
#  'isnan',
#  'isqrt',
#  'lcm',
#  'ldexp',
#  'lgamma',
#  'log',
#  'log10',
#  'log1p',
#  'log2',
#  'modf',
#  'nan',
#  'nextafter',
#  'perm',
#  'pi',
#  'pow',
#  'prod',
#  'radians',
#  'remainder',
#  'sin',
#  'sinh',
#  'sqrt',
#  'sumprod',
#  'tan',
#  'tanh',
#  'tau',
#  'trunc',
#  'ulp']

# %%
help(math.cos)
# Out:
# Help on built-in function cos in module math:
#
# cos(x, /)
#     Return the cosine of x (measured in radians).

# %%
x = 10
x = x + 1
print(x)
# Out:
# 11

# %%
nums = [1, 2]
nums.append(3)
print(nums)
# Out:
# [1, 2, 3]

# %%
count = 5
count = count + 1
print(count)
# Out:
# 6

# %%
avg = 3.5
avg = avg * 2
print(avg)
# Out:
# 7.0

# %%
age = 20
is_adult = age >= 18
print(age)
# Out:
# 20

# %%
name  = "carter"
first = name[0]
name = name + "wind"

# %%
text = " Hello "
text.strip()
text.upper()
text.replace("H", "1")
# Out:
# ' 1ello '

# %%
text.upper()
# Out:
# ' HELLO '

# %%
text.strip()
# Out:
# 'Hello'

# %%
nums = [1,2,3]
nums.append(4)
nums[1]
# Out:
# 2

# %%
nums.append(5)
print(nums)
# Out:
# [1, 2, 3, 4, 5]

# %%
nums.pop()
# Out:
# 5

# %%
nums.insert(0, 10)
print(nums)
# Out:
# [10, 1, 2, 3, 4]

# %%
nums.remove(2)
print(nums)
# Out:
# [10, 1, 3, 4]

# %%
point = (3,4)
point[0]
# Out:
# 3

# %%
student = {"name":"allice", "age":20, "country":"usa", "zipcode":76028, "state":"texas", "city":"burleson"}
student["age"] = 21

# %%
print(student)
# Out:
# {'name': 'allice', 'age': 21, 'country': 'usa', 'zipcode': 76028, 'state': 'texas', 'city': 'burleson'}

# %%
student.keys()
# Out:
# dict_keys(['name', 'age', 'country', 'zipcode', 'state', 'city'])

# %%
student.values()
# Out:
# dict_values(['allice', 21, 'usa', 76028, 'texas', 'burleson'])

# %%
student.items()
# Out:
# dict_items([('name', 'allice'), ('age', 21), ('country', 'usa'), ('zipcode', 76028), ('state', 'texas'), ('city', 'burleson')])

# %%
ids = {1,2,3}
ids.add(4)
3 in ids
# Out:
# True

# %%
import math
Area=float(input("What is the area?: "))
Equation = math.sqrt(Area/math.pi)

if Area > 0:
    print(Equation)
else:
    print("Not acclible")
# Out:
# What is the area?:  10
# 1.7841241161527712

# %%
age = int(input("How old are you?: "))
if age >= 65:
    print("senior")
elif age >= 18:
    print("Adult")
else:
    print("minor")
# Out:
# How old are you?:  1
# minor

# %%
sum = 0.0
data = input(" ")
while data!=" ":
    number = float(data)
    sum += number
    data = input(" ")
    print(" ", sum)
# Out:
#   10
#   10
#   10.0
#   10
#   20.0
#   10
#   30.0
#   10
#   40.0
#   100
#   50.0
#   10
#   150.0
#   160.0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[70], line 4
#       2 data = input(" ")
#       3 while data!=" ":
# ----> 4     number = float(data)
#       5     sum += number
#       6     data = input(" ")
#
# ValueError: could not convert string to float: ''

# %%
name = "zane"

# %%
name[0]
# Out:
# 'z'

# %%
name[-1]
# Out:
# 'e'

# %%
name = "myfile.txt"

# %%
name[0:]
# Out:
# 'myfile.txt'

# %%
name[0:3]
# Out:
# 'myf'

# %%
name[-3:]
# Out:
# 'txt'

# %%
files = ["file.txt", "filel.txt", "file.exc"]
for filename in files:
    if ".txt" in filename: 
        print(filename)
# Out:
# file.txt
# filel.txt

# %%
message = "Hello"
key = 2

encrypted = [ord(a) ^ key for c in message]
print(encrypted)
# Out:
# [67, 67, 67, 67, 67]
